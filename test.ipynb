# %%
import torch
 
# 假设checkpoint文件名为'checkpoint.pth'
checkpoint_path = '/home/hwj/workspace/results/hebb/result/network/4SoftHebbCnnCIFAR_ft/models/checkpoint.pth.tar'
checkpoint = torch.load(checkpoint_path)
 
# 打印checkpoint中的所有键
print(checkpoint.keys())
 
# 查看模型权重
print(checkpoint['state_dict'])
 
# 查看优化器状态
print(checkpoint['config'])
 
# 查看epoch数
print(checkpoint['epoch'])
# Out:
# dict_keys(['state_dict', 'config', 'epoch'])
# OrderedDict([('blocks.0.operations.0.running_mean', tensor([0.4966, 0.4841, 0.4464], device='cuda:1')), ('blocks.0.operations.0.running_var', tensor([0.0626, 0.0610, 0.0696], device='cuda:1')), ('blocks.0.operations.0.num_batches_tracked', tensor(50000, device='cuda:1')), ('blocks.0.layer.weight', tensor([[[[ 2.8353e-01, -1.3969e-01, -1.3559e-01,  6.0654e-01,  6.6853e-01],
#           [-7.6822e-02,  1.7154e-01, -9.6654e-01,  6.6814e-01, -4.9305e-01],
#           [-3.1692e-01,  3.9432e-01, -7.2991e-01,  5.7197e-01,  4.6897e-01],
#           [ 1.7163e-01,  3.0169e-01, -6.7085e-01,  5.4731e-01, -1.1718e-01],
#           [-3.4850e-01, -9.3752e-02, -4.4763e-01,  1.1746e-01, -8.5447e-02]],
#
#          [[-3.6520e-01, -2.1559e-01, -8.2138e-01,  7.2107e-01,  7.1449e-01],
#           [ 2.3020e-01, -2.8629e-01, -6.8724e-01, -8.0226e-02,  2.2215e-01],
#           [ 8.7933e-03,  2.1257e-01, -1.1439e+00,  2.1758e-01,  9.1679e-01],
# ...
